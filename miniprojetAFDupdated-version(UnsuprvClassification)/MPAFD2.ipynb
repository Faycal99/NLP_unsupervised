# %% [raw]
# Market basket analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori

# %%
df =pd.read_csv("store_data.csv",header=None)
#pandas considerer la premiere ligne comme un header

# %%
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
#Nettoyage et praparation des donnes textuelles
records=[]

# %%
df.shape
# Out:
# (7501, 20)

# %%
for i in range(7501):
    records.append([str(df.values[i,j]) for j in range(20) if str(df.values[i,j]) != "nan" ])#la plus long transaction contient 20 articles
    #on supprime les nan

# %%
records[1]
# Out:
# ['burgers', 'meatballs', 'eggs']

# %%
len(records)
# Out:
# 7501

# %%
#Application de l algorithme apriyori
Association_rules=apriori(records,min_support=0.0045,min_confidence=0.1,min_lift=3,min_length=2)

# %%
print(type(Association_rules))
# Out:
# <class 'generator'>

# %%
#casting de ce generatot vers une list
Association_rules_list=list(Association_rules)

# %%
list(Association_rules)
# Out:
# []

# %%
 for item in Association_rules_list:
        print(item,"\n\n\n")
# Out:
# RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)])
#
#
#
# RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)])
#
#
#
# RelationRecord(items=frozenset({'pasta', 'escalope'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)])
#
#
#
# ...

# %%
for item in Association_rules_list:
    pair=item [0]
    items=[x for x in pair]
    print("Rule:" +items[0]+"-->"+items[1])
    print("Support:"+str(item[1]))
    print("Confidence:"+str(item[2][0][2]))
    print("Lift:"+str(item[2][0][2]))
    print("==========================")
# Out:
# Rule:light cream-->chicken
# Support:0.004532728969470737
# Confidence:0.29059829059829057
# Lift:0.29059829059829057
# ...
# Rule:escalope-->mushroom cream sauce
# Support:0.005732568990801226
# Confidence:0.3006993006993007
# Lift:0.3006993006993007
# ...
# Rule:pasta-->escalope
# Support:0.005865884548726837
# Confidence:0.3728813559322034
# Lift:0.3728813559322034
# ...
# Rule:ground beef-->herb & pepper
# Support:0.015997866951073192
# Confidence:0.1628222523744912
# Lift:0.1628222523744912
# ...
# Rule:ground beef-->tomato sauce
# Support:0.005332622317024397
# Confidence:0.3773584905660377
# Lift:0.3773584905660377
# ...
# Rule:whole wheat pasta-->olive oil
# Support:0.007998933475536596
# Confidence:0.12145748987854252
# Lift:0.12145748987854252
# ...
# Rule:shrimp-->pasta
# Support:0.005065991201173177
# Confidence:0.3220338983050847
# Lift:0.3220338983050847
# ...
# Rule:shrimp-->frozen vegetables
# Support:0.005332622317024397
# Confidence:0.23255813953488375
# Lift:0.23255813953488375
# ...
